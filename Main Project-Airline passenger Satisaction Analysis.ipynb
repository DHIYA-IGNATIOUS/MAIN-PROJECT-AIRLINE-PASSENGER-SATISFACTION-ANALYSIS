# %% [markdown]
# <div style="text-align:center;">
#   <h1 style="color:#2F2F4F; font-family:Trebuchet MS;">
#     ✈️ AIRLINE PASSENGER SATISFACTION ANALYSIS ✈️
#   </h1>
#   <img src="C:/Users/Dhiya.Ignatious/OneDrive - Wilhelmsen/Desktop/AIRLINE.jpg"
#        width="650"
#        style="border-radius:12px; box-shadow:0 4px 15px rgba(0,0,0,0.3);">
# </div>

# %% [markdown]
# # INTRODUCTION
#
# Airline passenger satisfaction is a key indicator of service quality and overall customer experience in the aviation industry. This project aims to analyze airline passenger satisfaction using a dataset that includes passenger demographics, flight details, service ratings, and satisfaction outcomes. Through data exploration and analysis, the study seeks to uncover patterns and relationships that influence satisfaction levels. The objective is to identify the most significant factors—such as flight delays, seat comfort, and inflight services—that affect the passenger experience, and to provide actionable insights that can help airlines enhance their operations, improve service quality, and strengthen customer loyalty.

# %% [markdown]
# # AIM & OBJECTIVES

# %% [markdown]
# Aim:
#
# To analyse airline passenger satisfaction data to uncover trends, service factors, and passenger experience drivers that influence overall satisfaction.
#
# Key Objectives:
#
# •	Service Quality Analysis:
# Identify which inflight services—seat comfort, inflight service, food & beverages, check-in, and boarding—have the most impact on passenger satisfaction.
#
# •	Passenger Demographics:
# Explore satisfaction patterns across demographics such as age groups, gender, and customer type (loyal vs. first-time passengers).
#
# •	Travel & Flight Insights:
# Examine how travel class, flight distance, and type of travel affect passenger satisfaction.
#
# •	Impact of Delays:
# Analyse the influence of departure and arrival delays on passenger satisfaction, classifying passengers as Delayed vs. On Time.
#
# •	Actionable Insights:
# Provide recommendations to airlines for improving service quality, customer experience, and loyalty based on data-driven findings.

# %% [markdown]
# # PROJECT OVERVIEW

# %% [markdown]
# This project will follow a structured data analysis lifecycle:
#
# Data Acquisition & Understanding:
# We begin with the airline passenger satisfaction dataset, which contains passenger demographics, flight details, service ratings, and satisfaction outcomes. The first step is to load the dataset and understand its structure, columns, and key variables.
#
# Data Cleaning & Preprocessing:
# This is a critical phase to ensure high-quality analysis. We will handle missing values (e.g., null arrival delays), remove duplicates, standardize text formats (e.g., formatting gender and customer type), and create derived features such as age groups and delay status.
#
# Exploratory Data Analysis (EDA):
# We will perform univariate, bivariate, and multivariate analysis using statistical summaries and visualizations. This includes bar charts for satisfaction distribution, pie charts for travel types and class, heatmaps for correlations between numeric features, and other plots to reveal patterns in service quality and passenger experience.
#
# Conclusion & Insights:
# We will synthesize findings into clear, actionable insights, summarizing the key factors that influence passenger satisfaction. Results will guide airlines in improving services, optimizing operations, and enhancing overall customer experience.

# %% [markdown]
# # DATA DESCRIPTION

# %% [markdown]
# Source URL:
# https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction

# %% [markdown]
# The airline passenger satisfaction dataset contains 103,904 records and 25 columns, capturing passenger demographics, flight details, service ratings, and satisfaction outcomes. This dataset can be used for various analyses such as service quality assessment, passenger experience evaluation, and operational improvement.
#
# 1.	Passenger Demographics & Travel Details
#
# •	Gender – Male or Female
# •	Age – Passenger age
# •	Customer Type – Loyalty status (Loyal or First-time)
# •	Type of Travel – Business or Personal
# •	Class – Travel class (Business, Eco, Eco Plus)
# •	Flight Distance – Distance of the flight in miles
#
# 2.	Service Ratings (1–5 scale)
#
# •	Inflight Wi-Fi service, Seat comfort, Food and drink, Inflight entertainment, On-board service, Check-in service, Gate location, Baggage handling, Inflight service, Cleanliness
#
# 3. Flight Performance & Satisfaction
#
# •	Departure Delay in Minutes – Delay at departure
# •	Arrival Delay in Minutes – Delay at arrival
# •	Satisfaction – Overall satisfaction (Satisfied / Neutral or Dissatisfied)
#
# 4.	Derived Features (after preprocessing)
#
# •	Age Group – Categorized as Young, Adult, Middle-Age, Senior
# •	Delay Status – On-time or Delayed based on arrival delay
#
#
# This dataset enables exploration of how passenger demographics, inflight services, and flight performance affect overall satisfaction, providing actionable insights to improve airline operations and passenger experience.
# graphics, inflight services, and flight performance affect overall satisfaction, providing actionable insights to improve airline operations and passenger experience.

# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np

# %%
#Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set(style="whitegrid")

# %% [markdown]
# # 1.Data Loading and Initial Overview

# %%
import pandas as pd

train_df = pd.read_csv("C:/Users/Dhiya.Ignatious/OneDrive - Wilhelmsen/Desktop/DATA ANALYTICS/FINAL PROJECT OCT-NOV 2025/train.csv")
print("✅ Dataset loaded successfully!")
# Out:
# ✅ Dataset loaded successfully!

# %%
file_path = r"C:\Users\Dhiya.Ignatious\OneDrive - Wilhelmsen\Desktop\DATA ANALYTICS\FINAL PROJECT OCT-NOV 2025\train.csv"
df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
print(df.shape)
# Out:
# Dataset loaded successfully!
# (103904, 25)

# %% [markdown]
# # Getting Some Important Information About The Dataset:

# %% [markdown]
# 1-Head

# %%
print("🔹 First 5 Rows:")
display(df.head())
# Out:
# 🔹 First 5 Rows:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# 2.Tail

# %%
print("🔹 Last 5 Rows:")
display(df.tail())
# Out:
# 🔹 Last 5 Rows:
#         Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 103899      103899  94171  Female  disloyal Customer   23  Business travel
# 103900      103900  73097    Male     Loyal Customer   49  Business travel
# 103901      103901  68825    Male  disloyal Customer   30  Business travel
# 103902      103902  54173  Female  disloyal Customer   22  Business travel
# 103903      103903  62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 103899                                  1  ...                       2
# ...

# %% [markdown]
# 3.Shape

# %%
print("Shape of Dataset:")
print(df.shape)
# Out:
# Shape of Dataset:
# (103904, 25)

# %% [markdown]
# 4.Size

# %%
print("Size of Dataset:")
print(df.size)
# Out:
# Size of Dataset:
# 2597600

# %% [markdown]
# 5. Coloumn Names

# %%
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'satisfaction']

# %% [markdown]
# 6.Data Types

# %%
print("\n🔹 Data Types:")
print(df.dtypes)
# Out:
# 🔹 Data Types:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# ...

# %% [markdown]
# 7.Dataset Info Summary

# %%
print("\n🔹 Dataset Info:")
df.info()
# Out:
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %% [markdown]
# 8.Statistical summary of numeric columns

# %%
print("\n🔹 Statistical Summary:")
display(df.describe())
# Out:
# 🔹 Statistical Summary:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# # 2.Data Pre-processing

# %%
1.Missing values if any

# %%
print("\n🔹 Missing Values in Each Column:")
print(df.isnull().sum())
# Out:
# 🔹 Missing Values in Each Column:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# ...

# %% [markdown]
# 2.Clearing Missing values

# %%
train_df['Arrival Delay in Minutes'] = train_df['Arrival Delay in Minutes'].fillna(0)
print("✅ Missing values cleared")
# Out:
# ✅ Missing values cleared

# %% [markdown]
# 3.Ignore warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 4.Removing Duplicates

# %%
duplicate_rows = train_df[train_df.duplicated()]

# %%
print("Number of duplicate rows:", duplicate_rows.shape[0])
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# 5.Formating and standardisation

# %%
cat_cols = ['Gender','Customer Type','Type of Travel','Class','satisfaction']

for col in cat_cols:
    df[col] = df[col].astype(str).str.strip().str.title()

df['Gender'] = df['Gender'].replace({'Male':'M','Female':'F'})

print("✅ Categorical columns formatted!")
# Out:
# ✅ Categorical columns formatted!

# %% [markdown]
# 6.Checking Unique values

# %%
for col in cat_cols:
    print(col, ":", df[col].unique())
# Out:
# Gender : ['M' 'F']
# Customer Type : ['Loyal Customer' 'Disloyal Customer']
# Type of Travel : ['Personal Travel' 'Business Travel']
# Class : ['Eco Plus' 'Business' 'Eco']
# satisfaction : ['Neutral Or Dissatisfied' 'Satisfied']

# %% [markdown]
# 7.Derived Features

# %%
df['Age_Group'] = pd.cut(
    df['Age'],
    bins=[0,25,35,50,100],
    labels=['Young','Adult','Middle-Age','Senior']
)

df['Delay_Status'] = np.where(
    df['Arrival Delay in Minutes'] > 15, 'Delayed', 'On Time'
)

print("Derived features created successfully!")
# Out:
# Derived features created successfully!

# %% [markdown]
# 8.Convert to Categorical Data Types

# %%
cat_final = ['Gender','Customer Type','Type of Travel','Class','satisfaction','Age_Group','Delay_Status']

for col in cat_final:
    df[col] = df[col].astype('category')

print(df[cat_final].dtypes)
# Out:
# Gender            category
# Customer Type     category
# Type of Travel    category
# Class             category
# satisfaction      category
# Age_Group         category
# Delay_Status      category
# dtype: object

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# # UNIVARIATE ANALYSIS(Distribution & counts)

# %% [markdown]
# (a) Age Distribution

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Age'].dropna(), bins=20, kde=True)
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

print("Insight: Most passengers are in age ranges shown on the histogram (often 25-45).")
# Out:
# Insight: Most passengers are in age ranges shown on the histogram (often 25-45).

# %% [markdown]
# (b)Satisfaction ratio (pie) and counts

# %%
print("\nSatisfaction counts:")
print(df['satisfaction'].value_counts())
plt.figure(figsize=(5,5))
df['satisfaction'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Passenger Satisfaction Ratio')
plt.ylabel('')
plt.show()
print("Insight: See percent of Satisfied vs Neutral/Dissatisfied — indicates overall customer sentiment.")
# Out:
# Satisfaction counts:
# satisfaction
# Neutral Or Dissatisfied    58879
# Satisfied                  45025
# Name: count, dtype: int64
# Insight: See percent of Satisfied vs Neutral/Dissatisfied — indicates overall customer sentiment.

# %% [markdown]
# # BIVARIATE ANALYSIS(groupby, orderby, aggregation)

# %% [markdown]
# (a)Satisfaction by Customer Type (counts)

# %%
cust_satis = df.groupby(['Customer Type','satisfaction']).size().unstack(fill_value=0)
display(cust_satis)
# Out:
# satisfaction       Neutral Or Dissatisfied  Satisfied
# Customer Type
# Disloyal Customer                    14489       4492
# Loyal Customer                       44390      40533

# %% [markdown]
# (b)Sorted by total satisfied count

# %%
cust_total = cust_satis.copy()
cust_total['Total_satisfied'] = cust_total.get('Satisfied', 0)  # adjust label if your dataset differs
cust_total = cust_total.sort_values(by='Total_satisfied', ascending=False)
display(cust_total)

print("Insight: Loyal customers tend to have higher satisfied counts than disloyal customers.")
# Out:
# satisfaction       Neutral Or Dissatisfied  Satisfied  Total_satisfied
# Customer Type
# Loyal Customer                       44390      40533            40533
# Disloyal Customer                    14489       4492             4492
# Insight: Loyal customers tend to have higher satisfied counts than disloyal customers.

# %% [markdown]
# (c)Average flight distance by Class (groupby + sort)

# %%
avg_distance = df.groupby('Class')['Flight Distance'].mean().sort_values(ascending=False)
display(avg_distance)

print("Insight: Business class typically has higher average flight distance (long-haul passengers).")
# Out:
# Class
# Business    1675.976925
# Eco Plus     747.125567
# Eco          743.439748
# Name: Flight Distance, dtype: float64
# Insight: Business class typically has higher average flight distance (long-haul passengers).

# %% [markdown]
# PIVOT TABLE

# %% [markdown]
# Pivot: Flight Distance mean by Gender and Class

# %%
pivot_distance = pd.pivot_table(df, values='Flight Distance', index='Gender', columns='Class', aggfunc='mean')
display(pivot_distance)
print("Insight: Pivot table compares average distances across gender and class — helpful to spot differences.")
# Out:
# Class      Business         Eco    Eco Plus
# Gender
# F       1674.359891  743.455906  745.826991
# M       1677.606314  743.422904  748.566723
# Insight: Pivot table compares average distances across gender and class — helpful to spot differences.

# %% [markdown]
# # MULTIVARIATE (catplot / cross-tab)

# %%
sns.catplot(x='Customer Type', hue='satisfaction', col='Class', data=df, kind='count', height=4, aspect=0.9)
plt.suptitle('Customer Type vs Class vs Satisfaction', y=1.02)
plt.show()
print("Insight: Loyal + Business class subset shows highest satisfaction and economy + disloyal shows lower satisfaction.")
# Out:
# Insight: Loyal + Business class subset shows highest satisfaction and economy + disloyal shows lower satisfaction.

# %% [markdown]
# CORRELATION ANALYSIS & STATISTICAL SUMMARY

# %% [markdown]
# Correlation (using numeric columns)

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(9,7))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap (numeric features)')
plt.show()

# %% [markdown]
# # 4.VISUALISATION(Matplotlib / Seaborn / Plotly)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# 1 — Gender distribution(Bar Plot)

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Gender', data=df, hue='Gender', palette='pastel', legend=False)
plt.title('Gender Distribution of Passengers')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

print("🟢 Insight: The dataset has a nearly balanced ratio of male and female passengers.")
# Out:
# 🟢 Insight: The dataset has a nearly balanced ratio of male and female passengers.

# %% [markdown]
# 2-Satisfaction distribution(Pie chart)

# %%
df['satisfaction'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', colors=['lightgreen','salmon'], startangle=90)
plt.title('Passenger Satisfaction Ratio')
plt.ylabel('')
plt.show()

print("🟢 Insight: Majority of passengers are satisfied, indicating overall positive service quality.")
# Out:
# 🟢 Insight: Majority of passengers are satisfied, indicating overall positive service quality.

# %% [markdown]
# 3-Age Distribution(Histogram)

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['Age'], bins=20, kde=True, color='skyblue')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

print("🟢 Insight: Most passengers are between 25–45 years old, showing middle-aged adults form the majority of travelers.")
# Out:
# 🟢 Insight: Most passengers are between 25–45 years old, showing middle-aged adults form the majority of travelers.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# 3- Boxplot: Flight Distance by Class

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Class', y='Flight Distance', hue='Class', data=df, palette='muted', legend=False)
plt.title('Flight Distance by Class')
plt.xlabel('Class')
plt.ylabel('Flight Distance')
plt.show()

print("Insight: Business class has higher median distance and wider spread — long-haul passengers dominate this class.")
# Out:
# Insight: Business class has higher median distance and wider spread — long-haul passengers dominate this class.

# %% [markdown]
# 4-Boxplot: Arrival Delay vs Satisfaction

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='satisfaction', y='Arrival Delay in Minutes', hue='satisfaction', 
            data=df, palette='coolwarm', legend=False)
plt.title('Arrival Delay Distribution by Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Arrival Delay (Minutes)')
plt.show()

print("Insight: Dissatisfied passengers tend to have higher arrival delays — punctuality strongly affects satisfaction.")
# Out:
# Insight: Dissatisfied passengers tend to have higher arrival delays — punctuality strongly affects satisfaction.

# %% [markdown]
# 5-Scatter: Age vs Flight Distance colored by satisfaction

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='Age', y='Flight Distance', hue='satisfaction', data=df, alpha=0.6)
plt.title('Age vs Flight Distance by Satisfaction')
plt.xlabel('Age')
plt.ylabel('Flight Distance')
plt.legend(title='Satisfaction', bbox_to_anchor=(1.05,1), loc='upper left')
plt.show()
print("Insight: No clear linear trend between age and distance; satisfied passengers appear across ages.")
# Out:
# Insight: No clear linear trend between age and distance; satisfied passengers appear across ages.

# %% [markdown]
# 6-Subplots: Class distance and Delay vs Satisfaction

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

# Plot 1: Class vs Flight Distance
sns.boxplot(x='Class', y='Flight Distance', hue='Class', data=df, palette='pastel', legend=False, ax=axes[0])
axes[0].set_title('Flight Distance by Class')
axes[0].set_xlabel('Class')
axes[0].set_ylabel('Flight Distance')

# Plot 2: Satisfaction vs Arrival Delay
sns.boxplot(x='satisfaction', y='Arrival Delay in Minutes', hue='satisfaction', data=df, palette='coolwarm', legend=False, ax=axes[1])
axes[1].set_title('Arrival Delay vs Satisfaction')
axes[1].set_xlabel('Satisfaction')
axes[1].set_ylabel('Arrival Delay (Minutes)')

plt.tight_layout()
plt.show()

print("Insight: The first chart shows that Business class passengers travel longer distances, while the second indicates that higher delays lead to lower satisfaction — combining these views highlights how flight type and punctuality jointly affect passenger experience.")
# Out:
# Insight: The first chart shows that Business class passengers travel longer distances, while the second indicates that higher delays lead to lower satisfaction — combining these views highlights how flight type and punctuality jointly affect passenger experience.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# 7-Catplot

# %%
sns.catplot(x='Customer Type', hue='satisfaction', col='Class',
            data=df, kind='count', height=5, aspect=0.9, palette='coolwarm')
plt.subplots_adjust(top=0.8)
plt.suptitle('Customer Type vs Class vs Satisfaction')
plt.show()

print("🔵 Insight: Loyal customers in Business Class show the highest satisfaction.")
# Out:
# 🔵 Insight: Loyal customers in Business Class show the highest satisfaction.

# %% [markdown]
# 8-Correlation heatmap

# %%
plt.figure(figsize=(9,7))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Correlation Heatmap (Numeric Features)')
plt.show()
print("Insight: Look for strong +ve on service features vs satisfaction; strong +ve between departure/arrival delays.")
# Out:
# Insight: Look for strong +ve on service features vs satisfaction; strong +ve between departure/arrival delays.

# %% [markdown]
# # CONCLUSION & SUMMARY OF FINDINGS
#
# 🔑 Passenger Satisfaction Insights
#
# •	Overall Satisfaction: The majority of passengers report being satisfied, though a notable portion remains neutral or dissatisfied, especially on shorter or Economy flights.
#
# •	Demographics: Slightly more female passengers than male, but both genders are well represented. Satisfaction levels are relatively consistent across age groups.
#
# •	Class & Type of Travel: Passengers in Business and First class report higher satisfaction compared to Economy. Business travellers generally express greater satisfaction than personal travellers.
#
# •	Flight Distance & Delays: Longer flights tend to have higher satisfaction, particularly when delays are minimal. Arrival delays above 15 minutes significantly reduce passenger satisfaction.
#
# •	Service Features: Inflight services such as seat comfort, food and beverage quality, inflight entertainment, legroom, and cleanliness strongly correlate with overall satisfaction.

# %% [markdown]
# # 🌍 OPERATIONAL & SERVICE INSIGHTS
#
# Airlines can enhance passenger experience by focusing on high-impact service features like seat comfort, inflight service, and cleanliness.
#
# Delays are a major driver of dissatisfaction, highlighting the importance of timely flight operations and effective communication.
#
# Premium class passengers have higher expectations, so consistent quality in Business and First class is crucial.

# %% [markdown]
# # 📌 RECOMMENDATIONS
#
# 1. ✨ Enhance Key Service Features
#    Focus on improving seat comfort, food and beverage quality, inflight entertainment, legroom, and cleanliness, as these directly impact passenger satisfaction.
#
# 2. ⏱ Minimize Flight Delays
#    Invest in operational efficiency, proactive communication, and real-time updates to passengers to reduce dissatisfaction caused by delays.
#
# 3. 💺 Improve Economy Class Experience
#    Since the majority of passengers travel in Economy, enhancing comfort and service in this class can significantly boost overall satisfaction.
#
# 4. 🧳 Tailor Services for Frequent Flyers
#    Business travelers value efficiency and comfort—enhancing loyalty programs and premium services will improve satisfaction and retention.
#
# 5. 📊 Monitor and Act on Passenger Feedback
#    Regularly collect and analyze satisfaction data to identify trends, detect service gaps, and implement targeted improvements.
#
# 6. 👨‍✈️ Staff Training and Awareness
#    Equip airline staff with skills in customer service, problem-solving, and handling inflight issues to improve the overall passenger experience.

# %% [markdown]
# # OVERALL CONCLUSION:
#
# Passenger satisfaction is heavily influenced by service quality, class type, and operational efficiency. Airlines that strategically improve inflight services, reduce delays, and tailor experiences based on travel type and passenger demographics can increase customer loyalty and overall satisfaction.
